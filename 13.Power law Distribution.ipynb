# %% [markdown]
# ### Power law Distribution:
#    - it is following the 80-20 rule
#    - the distribution which follows the power law we called it as pareto distribution
#    - we have two distribution parameter
#
#          (alpha---scale/mean)
#          (Xm------SD)
#    - ccdf-----complement cumulative distribution function
#
# ###### Question:
# 1. what is pareto distribution
# 2. how to check it is pareto distribution -----log-log plot, Q-Q plot
# 3. how to analysis----to convert it in gaussian using box-cox transformation

# %% [raw]
# ## 14/05/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels import robust

# %%
a=np.random.parato

# %%
data=[23,45,67,89,90,101,102]
stats.probplot(data,dist='pareto',sparams=(2.5,),plot=plt)
plt.show()

# %%
stats.probplot(data,dist='pareto',sparams=(1.2,),plot=plt)
plt.show()

# %%
data=np.sort([23,45,67,89,90,101,102])
cdf= np.arange(1, len(data) + 1) / len(data)
ccdf=1-cdf
plt.loglog(data, ccdf, marker='o', linestyle='-', color='b')
plt.show()

# %% [raw]
# ## 15/05/2025

# %% [markdown]
# ### boxcox transformation:
#
#    - X~pareto distribution(alpha,Xm)
#
#          x1,x2,x3-----xn------pareto
#
#    - Y~GD(mean,sigma)
#
#          y1,y2,y3-------yn------gaussian
#
#    - import scipy.stats as stats
#
#
#          Syntax:stats.boxcox(x)------>lambda
#
#    - y1=((x1^lambda)-1)/lambda  when lambda>0
#    - log(x)-----lambda=0
#    - when the lambda=0 then x follows the log normal distribution

# %%
a=np.random.pareto(2,5)
a
# Out:
# array([0.18977401, 0.03681489, 0.02823551, 1.29475197, 0.01142687])

# %%
data=np.random.gamma(shape=2,scale=2,size=100)
sns.histplot(data,kde=True ,color='red')
# Out:
# <Axes: ylabel='Count'>

# %%
t_data,lam=stats.boxcox(data)

# %%
sns.histplot(t_data,kde=True ,color='blue')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ##### **imp*all transformation:log,recipocal,square
# ##### ***Gaussian distribution
#
# ### Weibull Distribution:
#    - it is a non gaussian distribution
#    - the distribution parameters are lambda(mean),k(SD)
#    - to convert Weibull distribution into gaussian we can use the boxcox transformation
#
# #### Gamma:
#    - it is also follows the power law
#    - it is non gaussian as well pareto
#    - the distribution parameter for gamma is alpha(mean) and theta(SD)
# n

# %%
# !pip install requests

# %%
import requests

# %%
response=requests.get("https://www.trustpilot.com/review/www.amazon.com")
response
# Out:
# <Response [200]>

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="shortcut icon" type="image/x-icon" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon.ico"/><link rel="manifest" href="/manifest.json"/><meta name="application-name" content="Trustpilot"/><meta name="theme-color" content="#1c1c1c"/><link rel="apple-touch-icon" sizes="180x180" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/apple-touch-icon.png"/><link rel="icon" type="image/png" sizes="32x32" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/favicon-16x16.png"/><link rel="mask-icon" href="https://cdn.trustpilot.net/brand-assets/4.3.0/favicons/safari-pinned-tab.svg" color="#00b67a"/><meta name="apple-mobile-web-app-title" content="Trustpilot"/><meta name="msapplication-TileCo
# ...

# %%
#extract all the urls
#remove tags get the text
